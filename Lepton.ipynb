# %% [markdown]
# this is the example code from the Pi that Dr. Edwards wrote
# last updated: N.A.

# %%
from flirpy.camera.lepton import Lepton
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
camera = Lepton()

# %%
img=camera.grab()
print(camera)
print(img)
plt.imshow(img, interpolation='nearest')
plt.show()
# Out:
# <flirpy.camera.lepton.Lepton object at 0xa6dd8570>
# [[30876 30853 30811 ... 30266 30117 30093]
#  [30845 30800 30693 ... 30119 30078 30028]
#  [30761 30681 30559 ... 30038 30011 29989]
#  ...
#  [30826 30830 30840 ... 29878 29857 29863]
#  [30849 30842 30843 ... 29884 29859 29876]
#  [30857 30840 30843 ... 29865 29861 29884]]

# %%
print(camera.frame_count)
# Out:
# 155

# %%
camera.close()

# %%
import time
with Lepton() as camera:
    _ = camera.grab()
    tstart = time.time()
    for _ in range(20):
        image = camera.grab()
        tend = time.time()
        print(camera.frame_count)
# Out:
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328

# %%
tend-tstart
# Out:
# 2.2717654705047607
